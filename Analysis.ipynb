# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedcnn1.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedcnn1.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedcnn2.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedcnn2.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[16184 20816]
#  [  746 44586]]
# [[17816 19184]
#  [  817 44515]]
# [[16283   647]
#  [ 2350 63052]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('CNN1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('CNN2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby CNN1')
pl.ylabel('by CNN2\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedcnn2.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedcnn2.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedcnn3.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedcnn3.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[17816 19184]
#  [  817 44515]]
# [[17850 19150]
#  [  861 44471]]
# [[17606  1027]
#  [ 1105 62594]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('CNN2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('CNN3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby CNN2')
pl.ylabel('by CNN3\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedcnn3.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedcnn3.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedcnn1.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedcnn1.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[17850 19150]
#  [  861 44471]]
# [[16184 20816]
#  [  746 44586]]
# [[16342  2369]
#  [  588 63033]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('CNN3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('CNN1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby CNN3')
pl.ylabel('by CNN1\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expected-cnn-lstm-1.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicted-cnn-lstm-1.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expected-cnn-lstm-2.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicted-cnn-lstm-2.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[ 6041 30959]
#  [  226 45106]]
# [[16387 20613]
#  [ 3192 42140]]
# [[ 5772   495]
#  [13807 62258]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('CNN-LSTM1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('CNN-LSTM2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby CNN-LSTM1')
pl.ylabel('by CNN-LSTM2\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expected-cnn-lstm-2.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicted-cnn-lstm-2.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expected-cnn-lstm-3.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicted-cnn-lstm-3.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[16387 20613]
#  [ 3192 42140]]
# [[17369 19631]
#  [  582 44750]]
# [[12773  6806]
#  [ 5178 57575]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('CNN-LSTM2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('CNN-LSTM3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby CNN-LSTM2')
pl.ylabel('by CNN-LSTM3\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expected-cnn-lstm-3.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicted-cnn-lstm-3.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expected-cnn-lstm-1.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicted-cnn-lstm-1.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[17369 19631]
#  [  582 44750]]
# [[ 6041 30959]
#  [  226 45106]]
# [[ 6034 11917]
#  [  233 64148]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('CNN-LSTM3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('CNN-LSTM1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby CNN-LSTM3')
pl.ylabel('by CNN-LSTM1\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expecteddnn1.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicteddnn1.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expecteddnn2.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicteddnn2.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[16524 20476]
#  [ 1556 43776]]
# [[15989 21011]
#  [ 1023 44309]]
# [[16929  1151]
#  [   83 64169]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('DNN1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('DNN2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby DNN1')
pl.ylabel('by DNN2\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expecteddnn2.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicteddnn2.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expecteddnn3.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicteddnn3.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[15989 21011]
#  [ 1023 44309]]
# [[15853 21147]
#  [  767 44565]]
# [[16264   748]
#  [  356 64964]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('DNN2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('DNN3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby DNN2')
pl.ylabel('by DNN3\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expecteddnn3.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicteddnn3.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expecteddnn4.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicteddnn4.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[15853 21147]
#  [  767 44565]]
# [[14885 22115]
#  [  524 44808]]
# [[15271  1349]
#  [  138 65574]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('DNN3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('DNN4\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby DNN3')
pl.ylabel('by DNN4\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expecteddnn4.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicteddnn4.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expecteddnn5.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicteddnn5.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[14885 22115]
#  [  524 44808]]
# [[15573 21427]
#  [  617 44715]]
# [[15054   355]
#  [ 1136 65787]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('DNN4\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('DNN5\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby DNN4')
pl.ylabel('by DNN5\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expecteddnn5.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predicteddnn5.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expecteddnn1.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predicteddnn1.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[15573 21427]
#  [  617 44715]]
# [[16524 20476]
#  [ 1556 43776]]
# [[16096    94]
#  [ 1984 64158]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('DNN5\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('DNN1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby DNN5')
pl.ylabel('by DNN1\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedgru.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedgru.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedgru1.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedgru1.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[19230 17770]
#  [ 4880 40452]]
# [[15526 21474]
#  [ 1613 43719]]
# [[16284  7826]
#  [  855 57367]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('GRU\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('GRU1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby GRU')
pl.ylabel('by GRU1\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedgru1.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedgru1.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedgru2.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedgru2.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[15526 21474]
#  [ 1613 43719]]
# [[15047 21953]
#  [  836 44496]]
# [[15553  1586]
#  [  330 64863]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('GRU1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('GRU2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby GRU1')
pl.ylabel('by GRU2\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedgru2.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedgru2.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedgru3.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedgru3.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[15047 21953]
#  [  836 44496]]
# [[15270 21730]
#  [  665 44667]]
# [[14867  1016]
#  [ 1068 65381]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('GRU2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('GRU3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby GRU2')
pl.ylabel('by GRU3\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedgru3.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedgru3.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedgru.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedgru.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[15270 21730]
#  [  665 44667]]
# [[19230 17770]
#  [ 4880 40452]]
# [[15859    76]
#  [ 8251 58146]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('GRU3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('GRU\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby GRU3')
pl.ylabel('by GRU\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedlstm.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedlstm.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedlstm1.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedlstm1.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[20903 16097]
#  [ 7707 37625]]
# [[18986 18014]
#  [ 4620 40712]]
# [[20601  8009]
#  [ 3005 50717]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('LSTM\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('LSTM1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby LSTM')
pl.ylabel('by LSTM1\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedlstm1.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedlstm1.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedlstm2.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedlstm2.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[18986 18014]
#  [ 4620 40712]]
# [[13253 23747]
#  [  342 44990]]
# [[13547 10059]
#  [   48 58678]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('LSTM1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('LSTM2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby LSTM1')
pl.ylabel('by LSTM2\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedlstm2.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedlstm2.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedlstm3.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedlstm3.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[13253 23747]
#  [  342 44990]]
# [[14015 22985]
#  [  589 44743]]
# [[13585    10]
#  [ 1019 67718]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('LSTM2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('LSTM3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby LSTM2')
pl.ylabel('by LSTM3\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedlstm3.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedlstm3.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedlstm.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedlstm.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[14015 22985]
#  [  589 44743]]
# [[20903 16097]
#  [ 7707 37625]]
# [[12365  2239]
#  [16245 51483]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('LSTM3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('LSTM\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby LSTM3')
pl.ylabel('by LSTM\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedrnn.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedrnn.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedrnn1.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedrnn1.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[23448 13552]
#  [ 8765 36567]]
# [[14273 22727]
#  [  969 44363]]
# [[14378 17835]
#  [  864 49255]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('RNN\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('RNN1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby RNN')
pl.ylabel('by RNN1\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedrnn1.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedrnn1.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedrnn2.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedrnn2.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[14273 22727]
#  [  969 44363]]
# [[13948 23052]
#  [  852 44480]]
# [[14738   504]
#  [   62 67028]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('RNN1\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('RNN2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby RNN1')
pl.ylabel('by RNN2\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedrnn2.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedrnn2.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedrnn3.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedrnn3.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[13948 23052]
#  [  852 44480]]
# [[13411 23589]
#  [  627 44705]]
# [[14025   775]
#  [   13 67519]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('RNN2\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('RNN3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby RNN2')
pl.ylabel('by RNN3\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl
import numpy as np
import matplotlib.colors as mcolors
# Read the data
with open('res/expectedrnn3.txt', 'r') as infile:
    true_values = [int(i) for i in infile]
with open('res/predictedrnn3.txt', 'r') as infile:
    predictions = [int(i) for i in infile]
with open('res/expectedrnn.txt', 'r') as infile:
    true_values1 = [int(i) for i in infile]
with open('res/predictedrnn.txt', 'r') as infile:
    predictions1 = [int(i) for i in infile]

# Make confusion matrix
confusion = confusion_matrix(true_values, predictions)
confusion1 = confusion_matrix(true_values1, predictions1)
confusion2= confusion_matrix(predictions, predictions1)

print(confusion)
print(confusion1)
print(confusion2)
# Out:
# [[13411 23589]
#  [  627 44705]]
# [[23448 13552]
#  [ 8765 36567]]
# [[13460   578]
#  [18753 49541]]

# %%
classNames = ['Normal = 0','Attack = 1']
tick_marks = np.arange(len(classNames))
#confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion,cmap='Blues')
pl.title('RNN3\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks (tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion[i][j]=round(confusion[i][j],3)*100
        pl.text(j,i,str(confusion[i][j]))
pl.show()

#confusion1 = confusion1.astype('float') / confusion1.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion1,cmap='Blues')
pl.title('RNN\n')
pl.colorbar()
pl.xlabel('\nPredicted')
pl.ylabel('Expected\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion1[i][j]=round(confusion1[i][j],3)*100
        pl.text(j,i,str(confusion1[i][j]))
pl.show()

#confusion2 = confusion2.astype('float') / confusion2.sum(axis=1)[:, np.newaxis]
pl.matshow(confusion2,cmap='Blues')
pl.title('Predictions\n')
pl.colorbar()
pl.xlabel('\nby RNN3')
pl.ylabel('by RNN\n')
pl.xticks(tick_marks,classNames)
pl.yticks(tick_marks,classNames)
for i in range(2):
    for j in range(2):
        #confusion2[i][j]=round(confusion2[i][j],3)*100
        pl.text(j,i,str(confusion2[i][j]))
pl.show()
